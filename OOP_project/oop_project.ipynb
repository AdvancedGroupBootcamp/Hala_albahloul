# %%
#  import the necessary libraries

import pandas as pd
from datetime import date

# %%
#  CELL classes

class Computer():
    
    # constructor with default values
    
    def __init__(self,manufacturer=None,model=None,category=None,screenSize=None,screen=None,CPU=None,RAM=None, storage=None,
                 GPU=None,operatingSystem=None,operatingSystemVersion=None,weight=None,price=None,remaining=0 ):
        self.manufacturer=manufacturer
        self.model=model
        self.category=category
        self.screenSize=screenSize
        self.screen=screen
        self.CPU=CPU
        self.frequency=None
        self.RAM=RAM
        self.storage=storage
        self.GPU=GPU
        self.operatingSystem=operatingSystem
        self.operatingSystemVersion=operatingSystemVersion
        self.weight=weight
        self.price=price
        self.remaining=remaining
        self.purchases=0
     
    #static method to get laptop price
    def get_price(x):        
        return x.price
    
    #method to get laptop model
    def get_model(self):
        return self.model
    
    #custom method to set new price
    def set_new_price(self, new_price):
        self.price=new_price
        
    #method to set the CPU frequency attribut   
    def data_featuring(self):
        self.frequency=self.CPU.split(" ")[3]
   
    #method to extract the data from string
    def data_extracting(self,form):
        self.manufacturer=form.split(",")[0]
        self.model=form.split(",")[1]
        self.category=form.split(",")[2]
        self.screenSize=form.split(",")[3]
        self.screen=form.split(",")[4]
        self.CPU=form.split(",")[5]
        self.RAM=form.split(",")[6]
        self.storage=form.split(",")[7]
        self.GPU=form.split(",")[8]
        self.operatingSystem=form.split(",")[9]
        self.operatingSystemVersion=form.split(",")[10]
        self.weight=form.split(",")[11]
        self.price=form.split(",")[12]
        self.remaining=int(form.split(",")[13])
        
    #method to get laptop data as dictionary    
    def get_data_cleaned(self):
        return{
        "manufacturer":self.manufacturer,
        "model":self.model,
        "category":self.category,
        "screenSize":self.screenSize,
        "screen":self.screen,
        "CPU":self.CPU,
        "frequency":self.frequency,
        "RAM":self.RAM,
        "storage":self.storage,
        "GPU":self.GPU,
        "operatingSystem":self.operatingSystem,
        "operatingSystemVersion":self.operatingSystemVersion,
        "weight":self.weight,
        "price":self.price,
        "remaining":self.remaining,
        "purchases":self.purchases
            
        }

# %%
# laptops data as strings
l1="Apple,MacBook Pro,Ultrabook,13.3,IPS Panel Retina Display 2560x1600,Intel Core i5 2.3GHz,8GB,128GB SSD,Intel Iris Plus Graphics 640,macOS, ,1.37kg,1339,69"
l2="Apple,Macbook Air,Ultrabook,13.3,1440x900,Intel Core i5 1.8GHz,8GB,128GB Flash Storage,Intel HD Graphics 6000,macOS, ,1.34kg,898,94"
l3="HP,250 G6,Notebook,15.6,Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB,256GB SSD,Intel HD Graphics 620,No OS, ,1.86kg,575,00"
l4="Apple,MacBook Pro,Ultrabook,15.4,IPS Panel Retina Display 2880x1800,Intel Core i7 2.7GHz,16GB,512GB SSD,AMD Radeon Pro 455,macOS, ,1.83kg,2537,45"
l5="Apple,MacBook Pro,Ultrabook,13.3,IPS Panel Retina Display 2560x1600,Intel Core i5 3.1GHz,8GB,256GB SSD,Intel Iris Plus Graphics 650,macOS, ,1.37kg,1803,60"
l6="Acer,Aspire 3,Notebook,15.6,1366x768,AMD A9-Series 9420 3GHz,4GB,500GB HDD,AMD Radeon R5,Windows,10,2.1kg,400,00"
l7="Apple,MacBook Pro,Ultrabook,15.4,IPS Panel Retina Display 2880x1800,Intel Core i7 2.2GHz,16GB,256GB Flash Storage,Intel Iris Pro Graphics,Mac OS,X,2.04kg,2139,97"
l8="Apple,Macbook Air,Ultrabook,13.3,1440x900,Intel Core i5 1.8GHz,8GB,256GB Flash Storage,Intel HD Graphics 6000,macOS,,1.34kg,1158,70"
l9="Asus,ZenBook UX430UN,Ultrabook,14.0,Full HD 1920x1080,Intel Core i7 8550U 1.8GHz,16GB,512GB SSD,Nvidia GeForce MX150,Windows,10,1.3kg,1495,00"
l10="Acer,Swift 3,Ultrabook,14.0,IPS Panel Full HD 1920x1080,Intel Core i5 8250U 1.6GHz,8GB,256GB SSD,Intel UHD Graphics 620,Windows,10,1.6kg,770,00"
l11="HP,250 G6,Notebook,15.6,1366x768,Intel Core i5 7200U 2.5GHz,4GB,500GB HDD,Intel HD Graphics 620,No OS,,1.86kg,393,90"
l12="HP,250 G6,Notebook,15.6,Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB,500GB HDD,Intel HD Graphics 520,No OS,,1.86kg,344,99"
l13="Apple,MacBook Pro,Ultrabook,15.4,IPS Panel Retina Display 2880x1800,Intel Core i7 2.8GHz,16GB,256GB SSD,AMD Radeon Pro 555,macOS,,1.83kg,2439,97"
l14="Dell,Inspiron 3567,Notebook,15.6,Full HD 1920x1080,Intel Core i3 6006U 2GHz,4GB,256GB SSD,AMD Radeon R5 M430,Windows,10,2.2kg,498,90"
l15="Apple,MacBook 12,Ultrabook,12.0,IPS Panel Retina Display 2304x1440,Intel Core M m3 1.2GHz,8GB,256GB SSD,Intel HD Graphics 615,macOS,,0.92kg,1262,40"
l16="Apple,MacBook Pro,Ultrabook,13.3,IPS Panel Retina Display 2560x1600,Intel Core i5 2.3GHz,8GB,256GB SSD,Intel Iris Plus Graphics 640,macOS,,1.37kg,1518,55"
l17="Dell,Inspiron 3567,Notebook,15.6,Full HD 1920x1080,Intel Core i7 7500U 2.7GHz,8GB,256GB SSD,AMD Radeon R5 M430,Windows,10,2.2kg,745,00"
l18="Apple,MacBook Pro,Ultrabook,15.4,IPS Panel Retina Display 2880x1800,Intel Core i7 2.9GHz,16GB,512GB SSD,AMD Radeon Pro 560,macOS,,1.83kg,2858,00"
l19="Lenovo,IdeaPad 320-15IKB,Notebook,15.6,Full HD 1920x1080,Intel Core i3 7100U 2.4GHz,8GB,1TB HDD,Nvidia GeForce 940MX,No OS,,2.2kg,499,00"
l20="Dell,XPS 13,Ultrabook,13.3,IPS Panel Full HD / Touchscreen 1920x1080,Intel Core i5 8250U 1.6GHz,8GB,128GB SSD,Intel UHD Graphics 620,Windows,10,1.22kg,979,00"
l21="Asus,Vivobook E200HA,Netbook,11.6,1366x768,Intel Atom x5-Z8350 1.44GHz,2GB,32GB Flash Storage,Intel HD Graphics 400,Windows,10,0.98kg,191,90"
l22="Lenovo,Legion Y520-15IKBN,Gaming,15.6,IPS Panel Full HD 1920x1080,Intel Core i5 7300HQ 2.5GHz,8GB,128GB SSD +  1TB HDD,Nvidia GeForce GTX 1050,Windows,10,2.5kg,999,00"
      
#string list of existing laptops data    
l=[l1,l2,l3,l4,l5,l6,l7,l8,l9,l10,l11,l12,l13,l14,l15,l16,l17,l18,l19,l20,l21,l22]

# %%
#extract laptops data from the strings list to Computers object list
laptops=[]
for idx in range(len(l)):
    c = Computer()
    c.data_extracting(l[idx])
    c.data_featuring()
    laptops.append(c)

# %%
#Clients data class

class Clients():
    
    #constructor with 3 initial values
    def __init__(self,name,gender,age,email):
        self.name=name
        self.gender=gender
        self.age=age
        self.email=email
        self.purchese=0
        purchese_model=None
        date_of_purches=None
        
    #method to buy a laptop   
    def buy(self,Computer):
        
        #reduce the amount of the available laptops of the purchased laptop   
        Computer.remaining=Computer.remaining-1
        
        #increase the purchases of the laptop
        Computer.purchases+=1
        
        #increase the client purchases 
        self.purchese+=1
        
        #set the purchased model
        self.purchese_model=Computer.get_model()
        
        #set the date of purchase
        self.date_of_purches=date.today()
        
    #get the clients data as a dictionary    
    def get_data_cleaned(self):
        return{
            "name":self.name,
            "gender":self.gender,
            "age":self.age,
            "email":self.email,
            "number of purchese":self.purchese,
            "purchese model":self.purchese_model,
            "date_of_purches":self.date_of_purches
    
        }

# %%
#clients data as clients Objects
cl1=Clients("hala_albahloul","f",25,"hala.alb@gmail.com")
cl2=Clients("hanan_tuma","f",19,"hanan.tum@gmail.com")
cl3=Clients("rami_sem","m",30,"rami.sem@gmail.com")
cl4=Clients("lana_jan","f",20,"lana.jan@gmail.com")

#list of the clients
clients=[cl1,cl2,cl3,cl4]

# %%
#purchases
cl1.buy(laptops[6])
cl2.buy(laptops[1])
cl3.buy(laptops[4])
cl4.buy(laptops[20])

# %%
#CELL director summary about client
clients_info=[]
for client in clients:    
    clients_info.append(client.get_data_cleaned())
    

df=pd.DataFrame.from_records(clients_info)
df
# Out:
#              name gender  age                email  number of purchese  \
# 0  hala_albahloul      f   25   hala.alb@gmail.com                   1
# 1      hanan_tuma      f   19  hanan.tum@gmail.com                   1
# 2        rami_sem      m   30   rami.sem@gmail.com                   1
# 3        lana_jan      f   20   lana.jan@gmail.com                   1
#
#     purchese model date_of_purches
# 0      MacBook Pro      2022-09-18
# 1      Macbook Air      2022-09-18
# 2      MacBook Pro      2022-09-18
# 3  Vivobook E200HA      2022-09-18

# %%
#CELL director summary about laptops
laptops_info=[]
for lap in laptops:    
      laptops_info.append(lap.get_data_cleaned())
df=pd.DataFrame.from_records(laptops_info)
df
# Out:
#    manufacturer               model   category screenSize  \
# 0         Apple         MacBook Pro  Ultrabook       13.3
# 1         Apple         Macbook Air  Ultrabook       13.3
# 2            HP              250 G6   Notebook       15.6
# 3         Apple         MacBook Pro  Ultrabook       15.4
# 4         Apple         MacBook Pro  Ultrabook       13.3
# 5          Acer            Aspire 3   Notebook       15.6
# 6         Apple         MacBook Pro  Ultrabook       15.4
# 7         Apple         Macbook Air  Ultrabook       13.3
# 8          Asus     ZenBook UX430UN  Ultrabook       14.0
# 9          Acer             Swift 3  Ultrabook       14.0
# 10           HP              250 G6   Notebook       15.6
# 11           HP              250 G6   Notebook       15.6
# 12        Apple         MacBook Pro  Ultrabook       15.4
# 13         Dell       Inspiron 3567   Notebook       15.6
# 14        Apple          MacBook 12  Ultrabook       12.0
# ...
